# %%
#import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.legend_handler import HandlerBase
from matplotlib.text import Text
import seaborn as sns
# %matplotlib inline
Blackfriday=pd.read_csv("BlackFriday2.csv")

# %%
#Let us create a function to plot this
def count_plot(dataframe, column_name, title =None, hue = None):
    '''
    Function to plot seaborn count plot
    Input: Dataframe name that has to be plotted, column_name that has to be plotted, title for the graph
    Output: Plot the data as a count plot
    '''
    base_color = sns.color_palette()[0]
    sns.countplot(data = dataframe, x = column_name, hue=hue)
    plt.title(title)
    pass

# %%
#let us create an quick & simple bar plot based on pandos plot method
def simple_bar_plot(data, title = None):
    '''
    A simple bar plot based on pandas plot method
    Input: data to be plotted and title for the plot
    Output: the plotled graph
    '''
    data.plot("bar", title = title)
    pass

# %%
#Let us create class handler to get the legend displayed in the plot
class TextHandler(HandlerBase):
    def create_artists(self, legend, tup ,xdescent, ydescent,
                        width, height, fontsize,trans):
        '''
        Function to display legend for a plot
        Input: legend, tuple string, placement of x and y descent, width and hight, font for the legend
        Output: retuns the text for legend        
        '''
        tx = Text(width/2.,height/2,tup[0], fontsize=fontsize,
                  ha="center", va="center", color=tup[1], fontweight="bold")
        return [tx]

# %%
Blackfriday
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# 5       1000003  P00193542      M  26-35          15             A
# 6       1000004  P00184942      M  46-50           7             B
# 7       1000004  P00346142      M  46-50           7             B
# 8       1000004   P0097242      M  46-50           7             B
# 9       1000005  P00274942      M  26-35          20             A
# 10      1000005  P00251242      M  26-35          20             A
# 11      1000005  P00014542      M  26-35          20             A
# 12      1000005  P00031342      M  26-35          20             A
# ...

# %%
Blackfriday.describe()
# Out:
#             User_ID    Occupation  Marital_Status  Product_Category_1  \
# count  5.375770e+05  537577.00000   537577.000000       537577.000000
# mean   1.002992e+06       8.08271        0.408797            5.295546
# std    1.714393e+03       6.52412        0.491612            3.750701
# min    1.000001e+06       0.00000        0.000000            1.000000
# 25%    1.001495e+06       2.00000        0.000000            1.000000
# 50%    1.003031e+06       7.00000        0.000000            5.000000
# 75%    1.004417e+06      14.00000        1.000000            8.000000
# max    1.006040e+06      20.00000        1.000000           18.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       370591.000000       164278.000000  537577.000000
# mean             9.842144           12.669840    9333.859853
# std              5.087259            4.124341    4981.022133
# min              2.000000            3.000000     185.000000
# ...

# %%
Blackfriday.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
Blackfriday.dtypes
# Out:
# User_ID                         int64
# Product_ID                     object
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                        int64
# dtype: object

# %%
Blackfriday.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %%
print('Number of people:',Blackfriday['User_ID'].nunique())
# Out:
# Number of people: 5891

# %%
sns.heatmap(Blackfriday.corr(), annot=True)

# %%
age_counts=Blackfriday['Age'].value_counts()*100
age_counts/100;
age_counts
y = Blackfriday[Blackfriday['Age']=='0-17'].count()[0]/100
e = Blackfriday[Blackfriday['Age']=='55+'].count()[0]
print('0-17:',y,"%")
print('55+:',round(Blackfriday[Blackfriday['Age']=='55+']['Purchase'].sum()/e,3))
# Out:
# 0-17: 147.07 %
# 55+: 9453.899

# %%
count_plot(Blackfriday,'Age')

# %%
agedf=Blackfriday['Purchase'].groupby(Blackfriday['Age']).sum()
print(agedf)
plt.plot(agedf,marker='o')
plt.title('Age vs. Purchase')
plt.xlabel('Age')
plt.ylabel('Total Purchase')
plt.grid(True)
plt.show()
# Out:
# Age
# 0-17      132659006
# 18-25     901669280
# 26-35    1999749106
# 36-45    1010649565
# 46-50     413418223
# 51-55     361908356
# 55+       197614842
# Name: Purchase, dtype: int64

# %%
count_plot(Blackfriday,"Age","Age Groups")

# %%
explode = (0.1,0,0,0,0,0,0.1)  
fig1, ax1 = plt.subplots(figsize=(8,6))
ax1.pie(Blackfriday['Age'].value_counts(), explode=explode,labels=['0-17','18-25','26-35','36-45','46-50','51-55','55+'], autopct='%1.1f%%',colors = ['lightskyblue','lightcoral','orange','yellow','grey','red','violet'],
        shadow=True, startangle=30)
ax1.axis('equal')  
plt.tight_layout()
plt.legend()
plt.show()

# %%
count_plot(Blackfriday,"Product_Category_1","Product_Category_1")

# %%
simple_bar_plot(Blackfriday["Product_ID"].value_counts(sort=True)[:10], title = "products people spend on Black Friday")

# %%
count_plot(Blackfriday,"Marital_Status","Number of single and married ")

# %%
count_plot(Blackfriday,"Gender","Number of male and femals")
m = Blackfriday[Blackfriday['Gender']=='M'].count()[0]
f = Blackfriday[Blackfriday['Gender']=='F'].count()[0]
print('Number of males:',m)
print('Number of females:',f)
# Out:
# Number of males: 405380
# Number of females: 132197

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
Blackfriday.hist(bins=50, figsize=(20,15))
plt.show()
